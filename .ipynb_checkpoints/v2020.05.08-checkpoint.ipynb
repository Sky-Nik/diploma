# %%
import numpy as np
from scipy import sparse
from matplotlib import pyplot as plt
import time
import codecs

# %%
plt.rcParams['figure.figsize'] = (10, 5)

# %%
def save_results_to_tbl(results, sizes, fn, caption):
    with codecs.open(f'tbl/{fn}.tex', 'w', 'utf-8') as out:
        # head
        out.write('\\begin{table}[H]\n')
        out.write('\t\\centering\n')

        # body
        out.write('\t\\begin{tabular}{|c||' + 'c|' * len(sizes) + '}' + '\\hline\n')
        out.write('\t\tРозмір задачі & ' + ' & '.join(map(str, sizes)) + ' \\\\ \\hline \\hline\n')
        for algo, result in results.items():
            out.write('\t\t' + algo + ' & ' +
                      ' & '.join(map(lambda r: f'{r:.2f}'
                                     if type(r) is float else str(r), result.values())) +
                      ' \\\\ \\hline\n')
        out.write('\t\\end{tabular}\n')

        # tail
        out.write('\t\\caption{' + caption + '}\n')
        out.write('\\end{table}\n')

# %%
def save_results_to_tbl_pm(results, sizes, fn, caption):
    with codecs.open(f'tbl/{fn}.tex', 'w', 'utf-8') as out:
        # head
        out.write('\\begin{table}[H]\n')
        out.write('\t\\centering\n')

        # body
        end = ' \\\\ \\hline\n'
        out.write('\t\\begin{tabular}{|c||' + 'c|' * len(sizes) + '}' + '\\hline\n')
        out.write('\t\tРозмір задачі & ' + ' & '.join(map(str, sizes)) + ' \\\\ \\hline \\hline\n')
        for algo, result in results.items():
            out.write('\t\t' + algo + ' & ' +
                      ' & '.join(map(lambda r: f'{r[0]:.2f} $\\pm$ {r[1]:.2f}'
                                     if type(r[0]) is float else f'{r[0]} $\\pm$ {r[1]}', result.values())) +
                      ' \\\\ \\hline\n')
        out.write('\t\\end{tabular}\n')

        # tail
        out.write('\t\\caption{' + caption + '}\n')
        out.write('\\end{table}\n')

# %%
def save_results_to_img(results, sizes, fn, styles, title):
    plt.xscale('log')
    plt.yscale('log')
    for style, (algo, result) in zip(styles, results.items()):
        plt.plot(sizes, result.values(), style, label=algo)
    plt.xlabel('Розмір задачі', fontsize=16)
    plt.ylabel(title, fontsize=16)
    plt.legend(loc='best', fontsize=12)
    plt.grid(which='both')
    plt.savefig(f'img/{fn}.png', bbox_inches='tight')
    plt.show()

# %%
def save_results_to_img_pm(results, sizes, fn, styles, title):
    plt.xscale('log')
    plt.yscale('log')
    for style, (algo, result) in zip(styles, results.items()):
        plt.plot(sizes, [r[0] for r in result.values()], style, label=algo)
        plt.fill_between(sizes,
                         [r[0] - r[1] / 5 for r in result.values()], 
                         [r[0] + r[1] / 5 for r in result.values()],
                         color=style[0], alpha=.1)
    plt.xlabel('Розмір задачі', fontsize=16)
    plt.ylabel(title, fontsize=16)
    plt.legend(loc='best', fontsize=12)
    plt.grid(which='both')
    plt.savefig(f'img/{fn}.png', bbox_inches='tight')
    plt.show()

# %%
# pythonic way to implement generics (known as templates in C++)
from typing import Callable, TypeVar
T = TypeVar('T')

# %% [markdown]
# # Алгоритми

# %%
def korpelevich(x_initial: T,
                lambda_: float,
                A: Callable[[T], T],
                ProjectionOntoC: Callable[[T], T],
                tolerance: float = 1e-5,
                max_iterations: int = 1e4,
                debug: bool = False) -> T:
    start = time.time()

    # initialization
    iteration_n = 1
    x_current = x_initial

    while True:
        # step 1
        y_current = ProjectionOntoC(x_current - lambda_ * A(x_current))

        # stopping criterion
        if (np.linalg.norm(x_current - y_current) < tolerance or
            iteration_n == max_iterations):
            if debug:
                end = time.time()
                duration = end - start
                print(f'Took {iteration_n} iterations '
                      f'and {duration:.2f} seconds to converge.')
                return x_current, iteration_n, duration
            return x_current

        # step 2
        x_next = ProjectionOntoC(x_current - lambda_ * A(y_current))

        # next iteration
        iteration_n += 1
        x_current, x_next = x_next, None
        y_current = None

# %%
def tseng(x_initial: T,
          lambda_: float,
          A: Callable[[T], T],
          ProjectionOntoC: Callable[[T], T],
          tolerance: float = 1e-5,
          max_iterations: int = 1e4,
          debug: bool = False) -> T:
    start = time.time()

    # initialization
    iteration_n = 1
    x_current = x_initial

    while True:
        # step 1
        y_current = ProjectionOntoC(x_current - lambda_ * A(x_current))

        # stopping criterion
        if (np.linalg.norm(x_current - y_current) < tolerance or
            iteration_n == max_iterations):
            if debug:
                end = time.time()
                duration = end - start
                print(f'Took {iteration_n} iterations '
                      f'and {duration:.2f} seconds to converge.')
                return x_current, iteration_n, duration
            return x_current

        # step 2
        x_next = y_current - lambda_ * (A(y_current) - A(x_current))

        # next iteration
        iteration_n += 1
        x_current, x_next = x_next, None
        y_current = None

# %%
def cached_tseng(x_initial: T,
                 lambda_: float,
                 A: Callable[[T], T],
                 ProjectionOntoC: Callable[[T], T],
                 tolerance: float = 1e-5,
                 max_iterations: int = 1e4,
                 debug: bool = False) -> T:
    start = time.time()

    # initialization
    iteration_n = 1
    x_current = x_initial

    while True:
        # step 1
        A_x_current = A(x_current)
        y_current = ProjectionOntoC(x_current - lambda_ * A_x_current)

        # stopping criterion
        if (np.linalg.norm(x_current - y_current) < tolerance or
            iteration_n == max_iterations):
            if debug:
                end = time.time()
                duration = end - start
                print(f'Took {iteration_n} iterations '
                      f'and {duration:.2f} seconds to converge.')
                return x_current, iteration_n, duration
            return x_current

        # step 2
        x_next = y_current - lambda_ * (A(y_current) - A_x_current)

        # next iteration
        iteration_n += 1
        x_current, x_next = x_next, None
        y_current = None

# %%
def popov(x_initial: T,
          y_initial: T,
          lambda_: float,
          A: Callable[[T], T],
          ProjectionOntoC: Callable[[T], T],
          tolerance: float = 1e-5,
          max_iterations: int = 1e4,
          debug: bool = False) -> T:
    start = time.time()

    # initialization
    iteration_n = 1
    x_current = x_initial
    y_previous = y_initial

    while True:
        # step 1
        y_current = ProjectionOntoC(x_current - lambda_ * A(y_previous))
        
        # step 2
        x_next = ProjectionOntoC(x_current - lambda_ * A(y_current))

        # stopping criterion
        if (np.linalg.norm(x_current - y_current) < tolerance and
            np.linalg.norm(x_next - y_current) < tolerance or
            iteration_n == max_iterations):
            if debug:
                end = time.time()
                duration = end - start
                print(f'Took {iteration_n} iterations '
                      f'and {duration:.2f} seconds to converge.')
                return x_current, iteration_n, duration
            return x_current

        # next iteration
        iteration_n += 1
        x_current, x_next = x_next, None
        y_previous, y_current = y_current, None

# %%
def cached_popov(x_initial: T,
                 y_initial: T,
                 lambda_: float,
                 A: Callable[[T], T],
                 ProjectionOntoC: Callable[[T], T],
                 tolerance: float = 1e-5,
                 max_iterations: int = 1e4,
                 debug: bool = False) -> T:
    start = time.time()

    # initialization
    iteration_n = 1
    x_current = x_initial
    y_previous = y_initial
    A_y_previous, A_y_current = A(y_previous), None

    while True:
        # step 1
        y_current = ProjectionOntoC(x_current - lambda_ * A_y_previous)
        
        # step 2
        A_y_current = A(y_current)
        x_next = ProjectionOntoC(x_current - lambda_ * A_y_current)

        # stopping criterion
        if (np.linalg.norm(x_current - y_current) < tolerance and
            np.linalg.norm(x_next - y_current) < tolerance or
            iteration_n == max_iterations):
            if debug:
                end = time.time()
                duration = end - start
                print(f'Took {iteration_n} iterations '
                      f'and {duration:.2f} seconds to converge.')
                return x_current, iteration_n, duration
            return x_current

        # next iteration
        iteration_n += 1
        x_current, x_next = x_next, None
        y_previous, y_current = y_current, None
        A_y_previous, A_y_current = A_y_current, None

# %% [markdown]
# # Перша задача

# %%
def generate_matrix(size: int) -> np.matrix:
    matrix = np.zeros((size, size))
    for row in range(size):
        col = size - 1 - row
        if col < row:
            matrix[row, col] = 1
        if col > row:
            matrix[row, col] = -1
    return matrix

# %%
sizes = (1_000, 2_000, 5_000, 10_000)
algos = ('Корпелевич', 'Tseng', 'Кеш. Tseng', 'Попов', 'Кеш. Попов')
iters, times = {algo: {} for algo in algos}, {algo: {} for algo in algos}

# %%
for size in sizes:
    print(f'Розмір задачі = {size}:')
    a = generate_matrix(size)

    print('\tКорпелевич:', end=' ')
    _, iters['Корпелевич'][size], times['Корпелевич'][size] = korpelevich(
        x_initial=np.ones(size), lambda_=0.4,
        A=lambda x: a.dot(x), ProjectionOntoC=lambda x: x,
        tolerance=1e-3, max_iterations=1e4, debug=True)

    print('\tTseng:', end=' ')
    _, iters['Tseng'][size], times['Tseng'][size] = tseng(
        x_initial=np.ones(size), lambda_=0.4,
        A=lambda x: a.dot(x), ProjectionOntoC=lambda x: x,
        tolerance=1e-3, max_iterations=1e4, debug=True)

    print('\tКеш. Tseng:', end=' ')
    _, iters['Кеш. Tseng'][size], times['Кеш. Tseng'][size] = cached_tseng(
        x_initial=np.ones(size), lambda_=0.4,
        A=lambda x: a.dot(x), ProjectionOntoC=lambda x: x,
        tolerance=1e-3, max_iterations=1e4, debug=True)

    print('\tПопов:', end=' ')
    _, iters['Попов'][size], times['Попов'][size] = popov(
        x_initial=np.ones(size), y_initial=np.ones(size), lambda_=0.4,
        A=lambda x: a.dot(x), ProjectionOntoC=lambda x: x,
        tolerance=1e-3, max_iterations=1e4, debug=True)

    print('\tКеш. Попов:', end=' ')
    _, iters['Кеш. Попов'][size], times['Кеш. Попов'][size] = cached_popov(
        x_initial=np.ones(size), y_initial=np.ones(size), lambda_=0.4,
        A=lambda x: a.dot(x), ProjectionOntoC=lambda x: x,
        tolerance=1e-3, max_iterations=1e4, debug=True)

    print()
# Out:
# Розмір задачі = 1000:
# 	Корпелевич: Took 132 iterations and 0.14 seconds to converge.
# 	Tseng: Took 132 iterations and 0.15 seconds to converge.
# 	Кеш. Tseng: Took 132 iterations and 0.08 seconds to converge.
# 	Попов: Took 89 iterations and 0.05 seconds to converge.
# 	Кеш. Попов: Took 89 iterations and 0.03 seconds to converge.
#
# Розмір задачі = 2000:
# 	Корпелевич: Took 137 iterations and 0.66 seconds to converge.
# 	Tseng: Took 137 iterations and 0.97 seconds to converge.
# 	Кеш. Tseng: Took 137 iterations and 0.66 seconds to converge.
# 	Попов: Took 92 iterations and 0.42 seconds to converge.
# 	Кеш. Попов: Took 92 iterations and 0.21 seconds to converge.
#
# Розмір задачі = 5000:
# 	Корпелевич: Took 144 iterations and 4.82 seconds to converge.
# 	Tseng: Took 144 iterations and 7.62 seconds to converge.
# 	Кеш. Tseng: Took 144 iterations and 5.09 seconds to converge.
# 	Попов: Took 96 iterations and 3.30 seconds to converge.
# 	Кеш. Попов: Took 96 iterations and 1.71 seconds to converge.
#
# Розмір задачі = 10000:
# 	Корпелевич: Took 148 iterations and 19.35 seconds to converge.
# 	Tseng: Took 148 iterations and 28.69 seconds to converge.
# 	Кеш. Tseng: Took 148 iterations and 19.24 seconds to converge.
# 	Попов: Took 99 iterations and 12.91 seconds to converge.
# 	Кеш. Попов: Took 99 iterations and 6.54 seconds to converge.

# %%
save_results_to_tbl(times, sizes,
    fn='problem-1-time',
    caption='Час виконання, секунд')
save_results_to_tbl(iters, sizes,
    fn='problem-1-iter',
    caption='Число ітерацій')

# %%
save_results_to_img(times, sizes,
    fn='problem-1-time',
    styles=('r-', 'g-', 'g--', 'b-', 'b--'),
    title='Час виконання, секунд')

# %% [markdown]
# # Розріджені матриці

# %%
def generate_sparse_matrix(size: int) -> np.matrix:
    data, rows, cols = [], [], []
    for row in range(size):
        rows.append(row)
        col = size - 1 - row
        cols.append(col)
        if col < row:
            data.append(1)
        if col > row:
            data.append(-1)
    return sparse.coo_matrix((data, (rows, cols)), shape=(size, size))

# %%
sizes = (50_000, 100_000, 200_000, 500_000)
algos = ('Корпелевич', 'Tseng', 'Кеш. Tseng', 'Попов', 'Кеш. Попов')
iters, times = {algo: {} for algo in algos}, {algo: {} for algo in algos}

# %%
for size in sizes:
    print(f'Розмір задачі = {size}:')
    a = generate_sparse_matrix(size)

    print('\tКорпелевич:', end=' ')
    _, iters['Корпелевич'][size], times['Корпелевич'][size] = korpelevich(
        x_initial=np.ones(size), lambda_=0.4,
        A=lambda x: a.dot(x), ProjectionOntoC=lambda x: x,
        tolerance=1e-3, max_iterations=1e4, debug=True)

    print('\tTseng:', end=' ')
    _, iters['Tseng'][size], times['Tseng'][size] = tseng(
        x_initial=np.ones(size), lambda_=0.4,
        A=lambda x: a.dot(x), ProjectionOntoC=lambda x: x,
        tolerance=1e-3, max_iterations=1e4, debug=True)

    print('\tКеш. Tseng:', end=' ')
    _, iters['Кеш. Tseng'][size], times['Кеш. Tseng'][size] = cached_tseng(
        x_initial=np.ones(size), lambda_=0.4,
        A=lambda x: a.dot(x), ProjectionOntoC=lambda x: x,
        tolerance=1e-3, max_iterations=1e4, debug=True)
    
    print('\tPopov:', end=' ')
    _, iters['Попов'][size], times['Попов'][size] = popov(
        x_initial=np.ones(size), y_initial=np.ones(size), lambda_=0.4,
        A=lambda x: a.dot(x), ProjectionOntoC=lambda x: x,
        tolerance=1e-3, max_iterations=1e4, debug=True)

    print('\tКеш. Попов:', end=' ')
    _, iters['Кеш. Попов'][size], times['Кеш. Попов'][size] = cached_popov(
        x_initial=np.ones(size), y_initial=np.ones(size), lambda_=0.4,
        A=lambda x: a.dot(x), ProjectionOntoC=lambda x: x,
        tolerance=1e-3, max_iterations=1e4, debug=True)
    
    print()
# Out:
# Розмір задачі = 50000:
# 	Корпелевич: Took 159 iterations and 0.14 seconds to converge.
# 	Tseng: Took 159 iterations and 0.21 seconds to converge.
# 	Кеш. Tseng: Took 159 iterations and 0.17 seconds to converge.
# 	Popov: Took 106 iterations and 0.11 seconds to converge.
# 	Кеш. Попов: Took 106 iterations and 0.07 seconds to converge.
#
# Розмір задачі = 100000:
# 	Корпелевич: Took 164 iterations and 0.38 seconds to converge.
# 	Tseng: Took 164 iterations and 0.72 seconds to converge.
# 	Кеш. Tseng: Took 164 iterations and 0.46 seconds to converge.
# 	Popov: Took 109 iterations and 0.26 seconds to converge.
# 	Кеш. Попов: Took 109 iterations and 0.33 seconds to converge.
#
# Розмір задачі = 200000:
# 	Корпелевич: Took 169 iterations and 2.11 seconds to converge.
# 	Tseng: Took 169 iterations and 2.84 seconds to converge.
# 	Кеш. Tseng: Took 169 iterations and 2.36 seconds to converge.
# 	Popov: Took 112 iterations and 1.42 seconds to converge.
# 	Кеш. Попов: Took 112 iterations and 1.13 seconds to converge.
#
# Розмір задачі = 500000:
# 	Корпелевич: Took 175 iterations and 5.71 seconds to converge.
# 	Tseng: Took 175 iterations and 7.64 seconds to converge.
# 	Кеш. Tseng: Took 175 iterations and 6.48 seconds to converge.
# 	Popov: Took 117 iterations and 3.98 seconds to converge.
# 	Кеш. Попов: Took 117 iterations and 3.14 seconds to converge.

# %%
save_results_to_tbl(times, sizes,
    fn='problem-1-sparse-time',
    caption='Час виконання, секунд')
save_results_to_tbl(iters, sizes,
    fn='problem-1-sparse-iter',
    caption='Число ітерацій')

# %%
save_results_to_img(times, sizes,
    fn='problem-1-sparse-time',
    styles=('r-', 'g-', 'g--', 'b-', 'b--'),
    title='Час виконання, секунд')

# %% [markdown]
# # Друга задача

# %%
def generate_random_matrix(size: int) -> np.matrix:
    a = np.random.uniform(-5, 5, (size, size))
    b = np.random.uniform(-5, 5, (size, size))
    # skew-symmetric
    for row in range(size):
        for col in range(row):
            b[col, row] = -b[row, col]
    d = np.diag(np.random.uniform(0, .3, size))
    q = np.random.uniform(-500, 0, size)
    return a.dot(a.T) + b + d, q

# %%
def ProjectionOntoProbabilitySymplex(x: np.array) -> np.array:
    dimensionality = x.shape[0]
    x /= dimensionality
    sorted_x = np.flip(np.sort(x))
    prefix_sum = np.cumsum(sorted_x)
    to_compare = sorted_x + (1 - prefix_sum) / np.arange(1, dimensionality + 1)
    k = 0
    for j in range(1, dimensionality):
        if to_compare[j] > 0:
            k = j
    return dimensionality * np.maximum(np.zeros(dimensionality),
                                       x + (to_compare[k] - sorted_x[k]))

# %%
sizes = (100, 200, 500, 1000)
algos = ('Корпелевич', 'Tseng', 'Кеш. Tseng', 'Попов', 'Кеш. Попов')
iters, times = {algo: {} for algo in algos}, {algo: {} for algo in algos}

# %%
for size in sizes:
    print(f'Розмір задачі = {size}:')

    for algo in algos:
        iters[algo][size] = []
        times[algo][size] = []
 
    for _ in range(5):
        print(f'\tTry #{_ + 1}:')

        np.random.seed(_)
        M, q = generate_random_matrix(size)

        print('\t\tКорпелевич:', end=' ')
        _, iter_, time_ = korpelevich(
            x_initial=np.ones(size), lambda_=.4/np.linalg.norm(M),
            A=lambda x: M.dot(x) + q, ProjectionOntoC=ProjectionOntoProbabilitySymplex,
            tolerance=1e-3, max_iterations=1e4, debug=True)
        iters['Корпелевич'][size].append(iter_)
        times['Корпелевич'][size].append(time_)

        print('\t\tTseng:', end=' ')
        _, iter_, time_ = tseng(
            x_initial=np.ones(size), lambda_=.4/np.linalg.norm(M),
            A=lambda x: M.dot(x) + q, ProjectionOntoC=ProjectionOntoProbabilitySymplex,
            tolerance=1e-3, max_iterations=1e4, debug=True)
        iters['Tseng'][size].append(iter_)
        times['Tseng'][size].append(time_)

        print('\t\tКеш. Tseng:', end=' ')
        _, iter_, time_ = cached_tseng(
            x_initial=np.ones(size), lambda_=.4/np.linalg.norm(M),
            A=lambda x: M.dot(x) + q, ProjectionOntoC=ProjectionOntoProbabilitySymplex,
            tolerance=1e-3, max_iterations=1e4, debug=True)
        iters['Кеш. Tseng'][size].append(iter_)
        times['Кеш. Tseng'][size].append(time_)

        print('\t\tПопов:', end=' ')
        _, iter_, time_ = popov(
            x_initial=np.ones(size), y_initial=np.ones(size), lambda_=.4/np.linalg.norm(M),
            A=lambda x: M.dot(x) + q, ProjectionOntoC=ProjectionOntoProbabilitySymplex,
            tolerance=1e-3, max_iterations=1e4, debug=True)
        iters['Попов'][size].append(iter_)
        times['Попов'][size].append(time_)

        print('\t\tКеш. Попов:', end=' ')
        _, iter_, time_ = cached_popov(
            x_initial=np.ones(size), y_initial=np.ones(size), lambda_=.4/np.linalg.norm(M),
            A=lambda x: M.dot(x) + q, ProjectionOntoC=ProjectionOntoProbabilitySymplex,
            tolerance=1e-3, max_iterations=1e4, debug=True)
        iters['Кеш. Попов'][size].append(iter_)
        times['Кеш. Попов'][size].append(time_)

        print()

    print()
# Out:
# Розмір задачі = 100:
# 	Try #1:
# 		Корпелевич: Took 967 iterations and 0.65 seconds to converge.
# 		Tseng: Took 967 iterations and 0.49 seconds to converge.
# 		Кеш. Tseng: Took 967 iterations and 0.36 seconds to converge.
# 		Попов: Took 967 iterations and 0.56 seconds to converge.
# 		Кеш. Попов: Took 967 iterations and 0.45 seconds to converge.
#
# 	Try #2:
# 		Корпелевич: Took 1151 iterations and 0.68 seconds to converge.
# 		Tseng: Took 1151 iterations and 0.66 seconds to converge.
# 		Кеш. Tseng: Took 1151 iterations and 0.59 seconds to converge.
# 		Попов: Took 1151 iterations and 0.65 seconds to converge.
# 		Кеш. Попов: Took 1151 iterations and 0.55 seconds to converge.
#
# 	Try #3:
# 		Корпелевич: Took 1086 iterations and 0.63 seconds to converge.
# 		Tseng: Took 1086 iterations and 0.49 seconds to converge.
# 		Кеш. Tseng: Took 1086 iterations and 0.40 seconds to converge.
# 		Попов: Took 1086 iterations and 0.57 seconds to converge.
# 		Кеш. Попов: Took 1086 iterations and 0.49 seconds to converge.
#
# 	Try #4:
# 		Корпелевич: Took 1456 iterations and 0.77 seconds to converge.
# 		Tseng: Took 1456 iterations and 0.68 seconds to converge.
# 		Кеш. Tseng: Took 1456 iterations and 0.54 seconds to converge.
# 		Попов: Took 1456 iterations and 0.74 seconds to converge.
# 		Кеш. Попов: Took 1456 iterations and 0.68 seconds to converge.
#
# 	Try #5:
# 		Корпелевич: Took 1221 iterations and 0.66 seconds to converge.
# 		Tseng: Took 1221 iterations and 0.60 seconds to converge.
# 		Кеш. Tseng: Took 1221 iterations and 0.58 seconds to converge.
# 		Попов: Took 1221 iterations and 0.83 seconds to converge.
# 		Кеш. Попов: Took 1221 iterations and 0.67 seconds to converge.
#
#
# Розмір задачі = 200:
# 	Try #1:
# 		Корпелевич: Took 1849 iterations and 1.33 seconds to converge.
# 		Tseng: Took 1849 iterations and 1.06 seconds to converge.
# 		Кеш. Tseng: Took 1849 iterations and 1.11 seconds to converge.
# 		Попов: Took 1849 iterations and 1.57 seconds to converge.
# 		Кеш. Попов: Took 1849 iterations and 1.12 seconds to converge.
#
# 	Try #2:
# 		Корпелевич: Took 1672 iterations and 1.24 seconds to converge.
# 		Tseng: Took 1672 iterations and 0.91 seconds to converge.
# 		Кеш. Tseng: Took 1672 iterations and 0.77 seconds to converge.
# 		Попов: Took 1672 iterations and 1.21 seconds to converge.
# 		Кеш. Попов: Took 1672 iterations and 1.09 seconds to converge.
#
# 	Try #3:
# 		Корпелевич: Took 1715 iterations and 1.26 seconds to converge.
# 		Tseng: Took 1715 iterations and 0.91 seconds to converge.
# 		Кеш. Tseng: Took 1715 iterations and 0.77 seconds to converge.
# 		Попов: Took 1715 iterations and 1.28 seconds to converge.
# 		Кеш. Попов: Took 1715 iterations and 1.15 seconds to converge.
#
# 	Try #4:
# 		Корпелевич: Took 1638 iterations and 1.17 seconds to converge.
# 		Tseng: Took 1638 iterations and 0.88 seconds to converge.
# 		Кеш. Tseng: Took 1638 iterations and 0.75 seconds to converge.
# 		Попов: Took 1638 iterations and 1.21 seconds to converge.
# 		Кеш. Попов: Took 1638 iterations and 1.09 seconds to converge.
#
# 	Try #5:
# 		Корпелевич: Took 1843 iterations and 1.29 seconds to converge.
# 		Tseng: Took 1843 iterations and 0.98 seconds to converge.
# 		Кеш. Tseng: Took 1843 iterations and 0.87 seconds to converge.
# 		Попов: Took 1843 iterations and 1.31 seconds to converge.
# 		Кеш. Попов: Took 1843 iterations and 1.21 seconds to converge.
#
#
# Розмір задачі = 500:
# 	Try #1:
# 		Корпелевич: Took 2523 iterations and 3.41 seconds to converge.
# 		Tseng: Took 2523 iterations and 2.21 seconds to converge.
# 		Кеш. Tseng: Took 2523 iterations and 1.92 seconds to converge.
# 		Попов: Took 2523 iterations and 3.49 seconds to converge.
# 		Кеш. Попов: Took 2523 iterations and 3.04 seconds to converge.
#
# 	Try #2:
# 		Корпелевич: Took 2543 iterations and 3.51 seconds to converge.
# 		Tseng: Took 2543 iterations and 2.14 seconds to converge.
# 		Кеш. Tseng: Took 2543 iterations and 1.95 seconds to converge.
# 		Попов: Took 2543 iterations and 3.45 seconds to converge.
# 		Кеш. Попов: Took 2543 iterations and 3.09 seconds to converge.
#
# 	Try #3:
# 		Корпелевич: Took 2725 iterations and 3.69 seconds to converge.
# 		Tseng: Took 2725 iterations and 2.26 seconds to converge.
# 		Кеш. Tseng: Took 2725 iterations and 2.11 seconds to converge.
# 		Попов: Took 2725 iterations and 3.72 seconds to converge.
# 		Кеш. Попов: Took 2725 iterations and 3.31 seconds to converge.
#
# 	Try #4:
# 		Корпелевич: Took 2813 iterations and 3.87 seconds to converge.
# 		Tseng: Took 2813 iterations and 2.39 seconds to converge.
# 		Кеш. Tseng: Took 2813 iterations and 2.17 seconds to converge.
# 		Попов: Took 2813 iterations and 3.90 seconds to converge.
# 		Кеш. Попов: Took 2813 iterations and 3.54 seconds to converge.
#
# 	Try #5:
# 		Корпелевич: Took 2869 iterations and 4.04 seconds to converge.
# 		Tseng: Took 2869 iterations and 2.62 seconds to converge.
# 		Кеш. Tseng: Took 2869 iterations and 2.29 seconds to converge.
# 		Попов: Took 2869 iterations and 4.08 seconds to converge.
# 		Кеш. Попов: Took 2869 iterations and 3.53 seconds to converge.
#
#
# Розмір задачі = 1000:
# 	Try #1:
# 		Корпелевич: Took 3542 iterations and 9.12 seconds to converge.
# 		Tseng: Took 3542 iterations and 7.58 seconds to converge.
# 		Кеш. Tseng: Took 3542 iterations and 6.69 seconds to converge.
# 		Попов: Took 3542 iterations and 9.35 seconds to converge.
# 		Кеш. Попов: Took 3542 iterations and 7.39 seconds to converge.
#
# 	Try #2:
# 		Корпелевич: Took 3570 iterations and 9.57 seconds to converge.
# 		Tseng: Took 3570 iterations and 7.32 seconds to converge.
# 		Кеш. Tseng: Took 3570 iterations and 6.23 seconds to converge.
# 		Попов: Took 3570 iterations and 9.26 seconds to converge.
# 		Кеш. Попов: Took 3570 iterations and 7.42 seconds to converge.
#
# 	Try #3:
# 		Корпелевич: Took 3471 iterations and 8.82 seconds to converge.
# 		Tseng: Took 3471 iterations and 6.77 seconds to converge.
# 		Кеш. Tseng: Took 3471 iterations and 5.64 seconds to converge.
# 		Попов: Took 3471 iterations and 8.79 seconds to converge.
# 		Кеш. Попов: Took 3471 iterations and 7.53 seconds to converge.
#
# 	Try #4:
# 		Корпелевич: Took 3918 iterations and 10.21 seconds to converge.
# 		Tseng: Took 3918 iterations and 8.50 seconds to converge.
# 		Кеш. Tseng: Took 3918 iterations and 6.86 seconds to converge.
# 		Попов: Took 3918 iterations and 10.41 seconds to converge.
# 		Кеш. Попов: Took 3918 iterations and 8.58 seconds to converge.
#
# 	Try #5:
# 		Корпелевич: Took 3907 iterations and 9.95 seconds to converge.
# 		Tseng: Took 3907 iterations and 7.67 seconds to converge.
# 		Кеш. Tseng: Took 3907 iterations and 6.50 seconds to converge.
# 		Попов: Took 3907 iterations and 10.13 seconds to converge.
# 		Кеш. Попов: Took 3907 iterations and 8.12 seconds to converge.

# %%
for algo in algos:
    for size in sizes:
        iters[algo][size] = (int(np.mean(iters[algo][size])), int(np.std(iters[algo][size])))
        times[algo][size] = (np.mean(times[algo][size]), np.std(times[algo][size]))

# %%
save_results_to_tbl_pm(times, sizes,
    fn='problem-2-time',
    caption='Час виконання, секунд')
save_results_to_tbl_pm(iters, sizes,
    fn='problem-2-iter',
    caption='Число ітерацій')

# %%
save_results_to_img_pm(times, sizes,
    fn='problem-2-time',
    styles=('r-', 'g-', 'g--', 'b-', 'b--'),
    title='Час виконання, секунд')

# %% [markdown]
# # Адаптивні алгоритми

# %%
def adaptive_korpelevich(x_initial: T,
                         tau: float,
                         lambda_initial: float,
                         A: Callable[[T], T],
                         ProjectionOntoC: Callable[[T], T],
                         tolerance: float = 1e-5,
                         max_iterations: int = 1e4,
                         debug: bool = False) -> T:
    start = time.time()

    # initialization
    iteration_n = 1
    x_current = x_initial
    lambda_current = lambda_initial

    while True:
        # step 1
        y_current = ProjectionOntoC(x_current - lambda_current * A(x_current))

        # stopping criterion
        if (np.linalg.norm(x_current - y_current) < tolerance or
            iteration_n == max_iterations):
            if debug:
                end = time.time()
                duration = end - start
                print(f'Took {iteration_n} iterations '
                      f'and {duration:.2f} seconds to converge.')
                return x_current, iteration_n, duration
            return x_current

        # step 2
        x_next = ProjectionOntoC(x_current - lambda_current * A(y_current))

        # step 3
        if (A(x_current) - A(y_current)).dot(x_next - y_current) <= 0:
            lambda_next = lambda_current
        else:
            lambda_next = min(lambda_current, tau / 2 * 
                (np.linalg.norm(x_current - y_current) ** 2 + 
                 np.linalg.norm(x_next - y_current) ** 2) /
                    (A(x_current) - A(y_current)).dot(x_next - y_current))
        
        # next iteration
        iteration_n += 1
        x_current, x_next = x_next, None
        y_current = None
        lambda_current, lambda_next = lambda_next, None

# %%
def cached_adaptive_korpelevich(x_initial: T,
                                tau: float,
                                lambda_initial: float,
                                A: Callable[[T], T],
                                ProjectionOntoC: Callable[[T], T],
                                tolerance: float = 1e-5,
                                max_iterations: int = 1e4,
                                debug: bool = False) -> T:
    start = time.time()

    # initialization
    iteration_n = 1
    x_current = x_initial
    lambda_current = lambda_initial
    A_x_current, A_y_current = None, None

    while True:
        # step 1
        A_x_current = A(x_current)
        y_current = ProjectionOntoC(x_current - lambda_current * A_x_current)

        # stopping criterion
        if (np.linalg.norm(x_current - y_current) < tolerance or
            iteration_n == max_iterations):
            if debug:
                end = time.time()
                duration = end - start
                print(f'Took {iteration_n} iterations '
                      f'and {duration:.2f} seconds to converge.')
                return x_current, iteration_n, duration
            return x_current

        # step 2
        A_y_current = A(y_current)
        x_next = ProjectionOntoC(x_current - lambda_current * A_y_current)

        # step 3
        product = (A_x_current - A_y_current).dot(x_next - y_current)
        if product <= 0:
            lambda_next = lambda_current
        else:
            lambda_next = min(lambda_current, tau / 2 *
                (np.linalg.norm(x_current - y_current) ** 2 + 
                 np.linalg.norm(x_next - y_current) ** 2) / product)
        
        # next iteration
        iteration_n += 1
        x_current, x_next = x_next, None
        y_current = None
        lambda_current, lambda_next = lambda_next, None
        A_x_current, A_y_current = None, None

# %%
def adaptive_tseng(x_initial: T,
                   tau: float,
                   lambda_initial: float,
                   A: Callable[[T], T],
                   ProjectionOntoC: Callable[[T], T],
                   tolerance: float = 1e-5,
                   max_iterations: int = 1e4,
                   debug: bool = False) -> T:
    start = time.time()

    # initialization
    iteration_n = 1
    x_current = x_initial
    lambda_current = lambda_initial

    while True:
        # step 1
        y_current = ProjectionOntoC(x_current - lambda_current * A(x_current))

        # stopping criterion
        if (np.linalg.norm(x_current - y_current) < tolerance or
            iteration_n == max_iterations):
            if debug:
                end = time.time()
                duration = end - start
                print(f'Took {iteration_n} iterations '
                      f'and {duration:.2f} seconds to converge.')
                return x_current, iteration_n, duration
            return x_current

        # step 2
        x_next = y_current - lambda_current * (A(y_current) - A(x_current))

        # step 3
        # if np.all(A(x_current) == A(y_current)):
        if np.linalg.norm(A(x_current) - A(y_current)) < tolerance:
            lambda_next = lambda_current
        else:
            lambda_next = min(lambda_current, tau *
                np.linalg.norm(x_current - y_current) /
                np.linalg.norm(A(x_current) - A(y_current)))
        
        # next iteration
        iteration_n += 1
        x_current, x_next = x_next, None
        y_current = None
        lambda_current, lambda_next = lambda_next, None

# %%
def cached_adaptive_tseng(x_initial: T,
                          tau: float,
                          lambda_initial: float,
                          A: Callable[[T], T],
                          ProjectionOntoC: Callable[[T], T],
                          tolerance: float = 1e-5,
                          max_iterations: int = 1e4,
                          debug: bool = False) -> T:
    start = time.time()

    # initialization
    iteration_n = 1
    x_current = x_initial
    lambda_current = lambda_initial
    A_x_current = None
    A_y_current = None

    while True:
        # step 1
        A_x_current = A(x_current)
        y_current = ProjectionOntoC(x_current - lambda_current * A_x_current)

        # stopping criterion
        if (np.linalg.norm(x_current - y_current) < tolerance or
            iteration_n == max_iterations):
            if debug:
                end = time.time()
                duration = end - start
                print(f'Took {iteration_n} iterations '
                      f'and {duration:.2f} seconds to converge.')
                return x_current, iteration_n, duration
            return x_current

        # step 2
        A_y_current = A(y_current)
        x_next = y_current - lambda_current * (A_y_current - A_x_current)

        # step 3
        # if np.all(A_x_current == A_y_current):
        if np.linalg.norm(A_x_current - A_y_current) < tolerance:
            lambda_next = lambda_current
        else:
            lambda_next = min(lambda_current, tau *
                np.linalg.norm(x_current - y_current) /
                np.linalg.norm(A_x_current - A_y_current))
        
        # next iteration
        iteration_n += 1
        x_current, x_next = x_next, None
        y_current = None
        lambda_current, lambda_next = lambda_next, None
        A_x_current, A_y_current = None, None

# %%
def adaptive_popov(x_initial: T,
                   y_initial: T,
                   tau: float,
                   lambda_initial: float,
                   A: Callable[[T], T],
                   ProjectionOntoC: Callable[[T], T],
                   tolerance: float = 1e-5,
                   max_iterations: int = 1e4,
                   debug: bool = False) -> T:
    start = time.time()

    # initialization
    iteration_n = 1
    x_current = x_initial
    y_previous = y_initial
    lambda_current = lambda_initial

    while True:
        # step 1
        y_current = ProjectionOntoC(x_current - lambda_current * A(y_previous))
        
        # step 2
        x_next = ProjectionOntoC(x_current - lambda_current * A(y_current))

        # stopping criterion
        if (np.linalg.norm(x_current - y_current) < tolerance and
            np.linalg.norm(x_next - y_current) < tolerance or
            iteration_n == max_iterations):
            if debug:
                end = time.time()
                duration = end - start
                print(f'Took {iteration_n} iterations '
                      f'and {duration:.2f} seconds to converge.')
                return x_current, iteration_n, duration
            return x_current

        # step 3
        if (A(y_previous) - A(y_current)).dot(x_next - y_current) <= 0:
            lambda_next = lambda_current
        else:
            lambda_next = min(lambda_current, tau / 2 *
                (np.linalg.norm(y_previous - y_current) ** 2 +
                 np.linalg.norm(x_next - y_current) ** 2) /
                    (A(y_previous) - A(y_current)).dot(x_next - y_current))
        
        # next iteration
        iteration_n += 1
        x_current, x_next = x_next, None
        y_previous, y_current = y_current, None
        lambda_current, lambda_next = lambda_next, None

# %%
def cached_adaptive_popov(x_initial: T,
                          y_initial: T,
                          tau: float,
                          lambda_initial: float,
                          A: Callable[[T], T],
                          ProjectionOntoC: Callable[[T], T],
                          tolerance: float = 1e-5,
                          max_iterations: int = 1e4,
                          debug: bool = False) -> T:
    start = time.time()

    # initialization
    iteration_n = 1
    x_current = x_initial
    y_previous = y_initial
    lambda_current = lambda_initial
    A_y_previous, A_y_current = A(y_previous), None

    while True:
        # step 1
        y_current = ProjectionOntoC(x_current - lambda_current * A_y_previous)
        
        # step 2
        A_y_current = A(y_current)
        x_next = ProjectionOntoC(x_current - lambda_current * A_y_current)

        # stopping criterion
        if (np.linalg.norm(x_current - y_current) < tolerance and
            np.linalg.norm(x_next - y_current) < tolerance or
            iteration_n == max_iterations):
            if debug:
                end = time.time()
                duration = end - start
                print(f'Took {iteration_n} iterations '
                      f'and {duration:.2f} seconds to converge.')
                return x_current, iteration_n, duration
            return x_current

        # step 3
        product = (A_y_previous - A_y_current).dot(x_next - y_current)
        if product <= 0:
            lambda_next = lambda_current
        else:
            lambda_next = min(lambda_current, tau / 2 *
                (np.linalg.norm(y_previous - y_current) ** 2 +
                 np.linalg.norm(x_next - y_current) ** 2) / product)
        
        # next iteration
        iteration_n += 1
        x_current, x_next = x_next, None
        y_previous, y_current = y_current, None
        lambda_current, lambda_next = lambda_next, None
        A_y_previous, A_y_current = A_y_current, None

# %%
sizes = (1_000, 2_000, 5_000, 10_000)
algos = ('Адапт. Корпелевич', 'Кеш. адапт. Корпелевич',
         'Адапт. Tseng', 'Кеш. адапт. Tseng',
         'Адапт. Попов', 'Кеш. адапт. Попов')
iters, times = {algo: {} for algo in algos}, {algo: {} for algo in algos}

# %%
for size in sizes:
    print(f'Розмір задачі = {size}:')
    a = generate_matrix(size)

    print('\tАдапт. Корпелевич:', end=' ')
    _, iters['Адапт. Корпелевич'][size], times['Адапт. Корпелевич'][size] = \
          adaptive_korpelevich(x_initial=np.ones(size), tau=.9, lambda_initial=1,
                               A=lambda x: a.dot(x), ProjectionOntoC=lambda x: x,
                               tolerance=1e-3, max_iterations=1e4, debug=True)

    print('\tКеш. адапт. Корпелевич:', end=' ')
    _, iters['Кеш. адапт. Корпелевич'][size], times['Кеш. адапт. Корпелевич'][size] = \
          cached_adaptive_korpelevich(x_initial=np.ones(size), tau=.9, lambda_initial=1,
                                      A=lambda x: a.dot(x), ProjectionOntoC=lambda x: x,
                                      tolerance=1e-3, max_iterations=1e4, debug=True)

    print('\tАдапт. Tseng:', end=' ')
    _, iters['Адапт. Tseng'][size], times['Адапт. Tseng'][size] = \
          adaptive_tseng(x_initial=np.ones(size), tau=.9, lambda_initial=1,
                         A=lambda x: a.dot(x), ProjectionOntoC=lambda x: x,
                         tolerance=1e-3, max_iterations=1e4, debug=True)

    print('\tКеш. адапт. Tseng:', end=' ')
    _, iters['Кеш. адапт. Tseng'][size], times['Кеш. адапт. Tseng'][size] = \
          cached_adaptive_tseng(x_initial=np.ones(size), tau=.9, lambda_initial=1,
                                A=lambda x: a.dot(x), ProjectionOntoC=lambda x: x,
                                tolerance=1e-3, max_iterations=1e4, debug=True)

    print('\tАдапт. Попов:', end=' ')
    _, iters['Адапт. Попов'][size], times['Адапт. Попов'][size] = \
          adaptive_popov(x_initial=np.ones(size), y_initial=np.ones(size),
                         tau=.3, lambda_initial=1,
                         A=lambda x: a.dot(x), ProjectionOntoC=lambda x: x,
                         tolerance=1e-3, max_iterations=1e4, debug=True)

    print('\tКеш. адапт. Попов:', end=' ')
    _, iters['Кеш. адапт. Попов'][size], times['Кеш. адапт. Попов'][size] = \
          cached_adaptive_popov(x_initial=np.ones(size), y_initial=np.ones(size),
                                tau=.3, lambda_initial=1,
                                A=lambda x: a.dot(x), ProjectionOntoC=lambda x: x,
                                tolerance=1e-3, max_iterations=1e4, debug=True)
    
    print()
# Out:
# Розмір задачі = 1000:
# 	Адапт. Корпелевич: Took 125 iterations and 0.23 seconds to converge.
# 	Кеш. адапт. Корпелевич: Took 125 iterations and 0.09 seconds to converge.
# 	Адапт. Tseng: Took 125 iterations and 0.24 seconds to converge.
# 	Кеш. адапт. Tseng: Took 125 iterations and 0.09 seconds to converge.
# 	Адапт. Попов: Took 179 iterations and 0.31 seconds to converge.
# 	Кеш. адапт. Попов: Took 179 iterations and 0.08 seconds to converge.
#
# Розмір задачі = 2000:
# 	Адапт. Корпелевич: Took 129 iterations and 1.72 seconds to converge.
# 	Кеш. адапт. Корпелевич: Took 129 iterations and 0.61 seconds to converge.
# 	Адапт. Tseng: Took 129 iterations and 1.98 seconds to converge.
# 	Кеш. адапт. Tseng: Took 129 iterations and 0.60 seconds to converge.
# 	Адапт. Попов: Took 185 iterations and 2.45 seconds to converge.
# 	Кеш. адапт. Попов: Took 185 iterations and 0.45 seconds to converge.
#
# Розмір задачі = 5000:
# 	Адапт. Корпелевич: Took 135 iterations and 13.95 seconds to converge.
# 	Кеш. адапт. Корпелевич: Took 135 iterations and 4.58 seconds to converge.
# 	Адапт. Tseng: Took 135 iterations and 15.56 seconds to converge.
# 	Кеш. адапт. Tseng: Took 135 iterations and 4.49 seconds to converge.
# 	Адапт. Попов: Took 194 iterations and 19.62 seconds to converge.
# 	Кеш. адапт. Попов: Took 194 iterations and 3.24 seconds to converge.
#
# Розмір задачі = 10000:
# 	Адапт. Корпелевич: Took 139 iterations and 51.94 seconds to converge.
# 	Кеш. адапт. Корпелевич: Took 139 iterations and 18.06 seconds to converge.
# 	Адапт. Tseng: Took 139 iterations and 63.89 seconds to converge.
# 	Кеш. адапт. Tseng: Took 139 iterations and 18.93 seconds to converge.
# 	Адапт. Попов: Took 201 iterations and 82.65 seconds to converge.
# 	Кеш. адапт. Попов: Took 201 iterations and 14.58 seconds to converge.

# %%
save_results_to_tbl(times, sizes,
    fn='problem-1-adapt-time',
    caption='Час виконання, секунд')
save_results_to_tbl(iters, sizes,
    fn='problem-1-adapt-iter',
    caption='Число ітерацій')

# %%
save_results_to_img(times, sizes,
    fn='problem-1-adapt-time',
    styles=('r-', 'r--', 'g-', 'g--', 'b-', 'b--'),
    title='Час виконання, секунд')

# %%
sizes = (50_000, 100_000, 200_000, 500_000)
algos = ('Адапт. Корпелевич', 'Кеш. адапт. Корпелевич',
         'Адапт. Tseng', 'Кеш. адапт. Tseng',
         'Адапт. Попов', 'Кеш. адапт. Попов')
iters, times = {algo: {} for algo in algos}, {algo: {} for algo in algos}

# %%
for size in sizes:
    print(f'Розмір задачі = {size}:')
    a = generate_sparse_matrix(size)

    print('\tАдапт. Корпелевич:', end=' ')
    _, iters['Адапт. Корпелевич'][size], times['Адапт. Корпелевич'][size] = \
          adaptive_korpelevich(x_initial=np.ones(size), tau=.4, lambda_initial=1,
                               A=lambda x: a.dot(x), ProjectionOntoC=lambda x: x,
                               tolerance=1e-3, max_iterations=1e4, debug=True)

    print('\tКеш. адапт. Корпелевич:', end=' ')
    _, iters['Кеш. адапт. Корпелевич'][size], times['Кеш. адапт. Корпелевич'][size] = \
          cached_adaptive_korpelevich(x_initial=np.ones(size), tau=.4, lambda_initial=1,
                                      A=lambda x: a.dot(x), ProjectionOntoC=lambda x: x,
                                      tolerance=1e-3, max_iterations=1e4, debug=True)

    print('\tАдапт. Tseng:', end=' ')
    _, iters['Адапт. Tseng'][size], times['Адапт. Tseng'][size] = \
          adaptive_tseng(x_initial=np.ones(size), tau=.4, lambda_initial=1,
                         A=lambda x: a.dot(x), ProjectionOntoC=lambda x: x,
                         tolerance=1e-3, max_iterations=1e4, debug=True)

    print('\tКеш. адапт. Tseng:', end=' ')
    _, iters['Кеш. адапт. Tseng'][size], times['Кеш. адапт. Tseng'][size] = \
          cached_adaptive_tseng(x_initial=np.ones(size), tau=.4, lambda_initial=1,
                                A=lambda x: a.dot(x), ProjectionOntoC=lambda x: x,
                                tolerance=1e-3, max_iterations=1e4, debug=True)

    print('\tАдапт. Попов:', end=' ')
    _, iters['Адапт. Попов'][size], times['Адапт. Попов'][size] = \
          adaptive_popov(x_initial=np.ones(size), y_initial=np.ones(size),
                         tau=.4, lambda_initial=1,
                         A=lambda x: a.dot(x), ProjectionOntoC=lambda x: x,
                         tolerance=1e-3, max_iterations=1e4, debug=True)

    print("\tКеш. адапт. Попов: ", end="")
    _, iters['Кеш. адапт. Попов'][size], times['Кеш. адапт. Попов'][size] = \
          cached_adaptive_popov(x_initial=np.ones(size), y_initial=np.ones(size),
                                tau=.4, lambda_initial=1,
                                A=lambda x: a.dot(x), ProjectionOntoC=lambda x: x,
                                tolerance=1e-3, max_iterations=1e4, debug=True)
    
    print()
# Out:
# Розмір задачі = 50000:
# 	Адапт. Корпелевич: Took 160 iterations and 0.26 seconds to converge.
# 	Кеш. адапт. Корпелевич: Took 160 iterations and 0.13 seconds to converge.
# 	Адапт. Tseng: Took 160 iterations and 0.26 seconds to converge.
# 	Кеш. адапт. Tseng: Took 160 iterations and 0.13 seconds to converge.
# 	Адапт. Попов: Took 108 iterations and 0.30 seconds to converge.
# 	Кеш. адапт. Попов: Took 108 iterations and 0.08 seconds to converge.
#
# Розмір задачі = 100000:
# 	Адапт. Корпелевич: Took 165 iterations and 1.44 seconds to converge.
# 	Кеш. адапт. Корпелевич: Took 165 iterations and 1.17 seconds to converge.
# 	Адапт. Tseng: Took 165 iterations and 0.88 seconds to converge.
# 	Кеш. адапт. Tseng: Took 165 iterations and 0.49 seconds to converge.
# 	Адапт. Попов: Took 111 iterations and 0.92 seconds to converge.
# 	Кеш. адапт. Попов: Took 111 iterations and 0.38 seconds to converge.
#
# Розмір задачі = 200000:
# 	Адапт. Корпелевич: Took 170 iterations and 4.93 seconds to converge.
# 	Кеш. адапт. Корпелевич: Took 170 iterations and 3.01 seconds to converge.
# 	Адапт. Tseng: Took 170 iterations and 5.52 seconds to converge.
# 	Кеш. адапт. Tseng: Took 170 iterations and 3.82 seconds to converge.
# 	Адапт. Попов: Took 114 iterations and 3.82 seconds to converge.
# 	Кеш. адапт. Попов: Took 114 iterations and 2.39 seconds to converge.
#
# Розмір задачі = 500000:
# 	Адапт. Корпелевич: Took 176 iterations and 14.45 seconds to converge.
# 	Кеш. адапт. Корпелевич: Took 176 iterations and 9.02 seconds to converge.
# 	Адапт. Tseng: Took 176 iterations and 15.74 seconds to converge.
# 	Кеш. адапт. Tseng: Took 176 iterations and 8.50 seconds to converge.
# 	Адапт. Попов: Took 118 iterations and 9.38 seconds to converge.
# 	Кеш. адапт. Попов: Took 118 iterations and 4.52 seconds to converge.

# %%
save_results_to_tbl(times, sizes,
    fn='problem-1-sparse-adapt-time',
    caption='Час виконання, секунд')
save_results_to_tbl(iters, sizes,
    fn='problem-1-sparse-adapt-iter',
    caption='Число ітерацій')

# %%
save_results_to_img(times, sizes,
    fn='problem-1-sparse-adapt-time',
    styles=('r-', 'r--', 'g-', 'g--', 'b-', 'b--'),
    title='Час виконання, секунд')

# %%
sizes = (100, 200, 500, 1000)
algos = ('Адапт. Корпелевич', 'Кеш. адапт. Корпелевич',
         'Адапт. Tseng', 'Кеш. адапт. Tseng',
         'Адапт. Попов', 'Кеш. адапт. Попов')
iters, times = {algo: {} for algo in algos}, {algo: {} for algo in algos}

# %%
for size in sizes:
    print(f'Розмір задачі = {size}:')

    for algo in algos:
        iters[algo][size] = []
        times[algo][size] = []
 
    for _ in range(5):
        print(f'\tTry #{_ + 1}:')

        np.random.seed(_)
        M, q = generate_random_matrix(size)
        
        print('\t\tАдапт. Корпелевич:', end=' ')
        _, iter_, time_ = adaptive_korpelevich(
            x_initial=np.ones(size), tau=.4, lambda_initial=1,
            A=lambda x: M.dot(x) + q, ProjectionOntoC=ProjectionOntoProbabilitySymplex,
            tolerance=1e-3, max_iterations=1e4, debug=True)
        iters['Адапт. Корпелевич'][size].append(iter_)
        times['Адапт. Корпелевич'][size].append(time_)

        print('\t\tКеш. адапт. Корпелевич:', end=' ')
        _, iter_, time_ = cached_adaptive_korpelevich(
            x_initial=np.ones(size), tau=.4, lambda_initial=1,
            A=lambda x: M.dot(x) + q, ProjectionOntoC=ProjectionOntoProbabilitySymplex,
            tolerance=1e-3, max_iterations=1e4, debug=True)
        iters['Кеш. адапт. Корпелевич'][size].append(iter_)
        times['Кеш. адапт. Корпелевич'][size].append(time_)

        print('\t\tАдапт. Tseng:', end=' ')
        _, iter_, time_ = adaptive_tseng(
            x_initial=np.ones(size), tau=.4, lambda_initial=1,
            A=lambda x: M.dot(x) + q, ProjectionOntoC=ProjectionOntoProbabilitySymplex,
            tolerance=1e-3, max_iterations=1e4, debug=True)
        iters['Адапт. Tseng'][size].append(iter_)
        times['Адапт. Tseng'][size].append(time_)

        print('\t\tКеш. адапт. Tseng:', end=' ')
        _, iter_, time_ = cached_adaptive_tseng(
            x_initial=np.ones(size), tau=.4, lambda_initial=1,
            A=lambda x: M.dot(x) + q, ProjectionOntoC=ProjectionOntoProbabilitySymplex,
            tolerance=1e-3, max_iterations=1e4, debug=True)
        iters['Кеш. адапт. Tseng'][size].append(iter_)
        times['Кеш. адапт. Tseng'][size].append(time_)

        print('\t\tАдапт. Попов:', end=' ')
        _, iter_, time_ = adaptive_popov(
            x_initial=np.ones(size), y_initial=np.ones(size), tau=.4, lambda_initial=1,
            A=lambda x: M.dot(x) + q, ProjectionOntoC=ProjectionOntoProbabilitySymplex,
            tolerance=1e-3, max_iterations=1e4, debug=True)
        iters['Адапт. Попов'][size].append(iter_)
        times['Адапт. Попов'][size].append(time_)

        print('\t\tКеш. адапт. Попов:', end=' ')
        _, iter_, time_ = cached_adaptive_popov(
            x_initial=np.ones(size), y_initial=np.ones(size), tau=.4, lambda_initial=1,
            A=lambda x: M.dot(x) + q, ProjectionOntoC=ProjectionOntoProbabilitySymplex,
            tolerance=1e-3, max_iterations=1e4, debug=True)
        iters['Кеш. адапт. Попов'][size].append(iter_)
        times['Кеш. адапт. Попов'][size].append(time_)

        print()

    print()
# Out:
# Розмір задачі = 100:
# 	Try #1:
# 		Адапт. Корпелевич: Took 253 iterations and 0.28 seconds to converge.
# 		Кеш. адапт. Корпелевич: Took 253 iterations and 0.16 seconds to converge.
# 		Адапт. Tseng: Took 432 iterations and 0.40 seconds to converge.
# 		Кеш. адапт. Tseng: Took 432 iterations and 0.19 seconds to converge.
# 		Адапт. Попов: Took 349 iterations and 0.36 seconds to converge.
# 		Кеш. адапт. Попов: Took 349 iterations and 0.18 seconds to converge.
#
# 	Try #2:
# 		Адапт. Корпелевич: Took 305 iterations and 0.14 seconds to converge.
# 		Кеш. адапт. Корпелевич: Took 305 iterations and 0.08 seconds to converge.
# 		Адапт. Tseng: Took 530 iterations and 0.23 seconds to converge.
# 		Кеш. адапт. Tseng: Took 530 iterations and 0.11 seconds to converge.
# 		Адапт. Попов: Took 451 iterations and 0.21 seconds to converge.
# 		Кеш. адапт. Попов: Took 451 iterations and 0.10 seconds to converge.
#
# 	Try #3:
# 		Адапт. Корпелевич: Took 243 iterations and 0.11 seconds to converge.
# 		Кеш. адапт. Корпелевич: Took 243 iterations and 0.07 seconds to converge.
# 		Адапт. Tseng: Took 458 iterations and 0.38 seconds to converge.
# 		Кеш. адапт. Tseng: Took 458 iterations and 0.21 seconds to converge.
# 		Адапт. Попов: Took 302 iterations and 0.30 seconds to converge.
# 		Кеш. адапт. Попов: Took 302 iterations and 0.15 seconds to converge.
#
# 	Try #4:
# 		Адапт. Корпелевич: Took 372 iterations and 0.37 seconds to converge.
# 		Кеш. адапт. Корпелевич: Took 372 iterations and 0.23 seconds to converge.
# 		Адапт. Tseng: Took 533 iterations and 0.48 seconds to converge.
# 		Кеш. адапт. Tseng: Took 533 iterations and 0.25 seconds to converge.
# 		Адапт. Попов: Took 499 iterations and 0.49 seconds to converge.
# 		Кеш. адапт. Попов: Took 499 iterations and 0.25 seconds to converge.
#
# 	Try #5:
# 		Адапт. Корпелевич: Took 415 iterations and 0.38 seconds to converge.
# 		Кеш. адапт. Корпелевич: Took 415 iterations and 0.11 seconds to converge.
# 		Адапт. Tseng: Took 568 iterations and 0.24 seconds to converge.
# 		Кеш. адапт. Tseng: Took 568 iterations and 0.12 seconds to converge.
# 		Адапт. Попов: Took 553 iterations and 0.26 seconds to converge.
# 		Кеш. адапт. Попов: Took 553 iterations and 0.12 seconds to converge.
#
#
# Розмір задачі = 200:
# 	Try #1:
# 		Адапт. Корпелевич: Took 397 iterations and 0.22 seconds to converge.
# 		Кеш. адапт. Корпелевич: Took 397 iterations and 0.28 seconds to converge.
# 		Адапт. Tseng: Took 727 iterations and 0.76 seconds to converge.
# 		Кеш. адапт. Tseng: Took 727 iterations and 0.41 seconds to converge.
# 		Адапт. Попов: Took 577 iterations and 0.69 seconds to converge.
# 		Кеш. адапт. Попов: Took 577 iterations and 0.43 seconds to converge.
#
# 	Try #2:
# 		Адапт. Корпелевич: Took 395 iterations and 0.54 seconds to converge.
# 		Кеш. адапт. Корпелевич: Took 395 iterations and 0.39 seconds to converge.
# 		Адапт. Tseng: Took 660 iterations and 0.70 seconds to converge.
# 		Кеш. адапт. Tseng: Took 660 iterations and 0.35 seconds to converge.
# 		Адапт. Попов: Took 541 iterations and 0.30 seconds to converge.
# 		Кеш. адапт. Попов: Took 541 iterations and 0.16 seconds to converge.
#
# 	Try #3:
# 		Адапт. Корпелевич: Took 364 iterations and 0.20 seconds to converge.
# 		Кеш. адапт. Корпелевич: Took 364 iterations and 0.13 seconds to converge.
# 		Адапт. Tseng: Took 644 iterations and 0.32 seconds to converge.
# 		Кеш. адапт. Tseng: Took 644 iterations and 0.33 seconds to converge.
# 		Адапт. Попов: Took 540 iterations and 0.63 seconds to converge.
# 		Кеш. адапт. Попов: Took 540 iterations and 0.40 seconds to converge.
#
# 	Try #4:
# 		Адапт. Корпелевич: Took 363 iterations and 0.45 seconds to converge.
# 		Кеш. адапт. Корпелевич: Took 363 iterations and 0.29 seconds to converge.
# 		Адапт. Tseng: Took 736 iterations and 0.80 seconds to converge.
# 		Кеш. адапт. Tseng: Took 736 iterations and 0.42 seconds to converge.
# 		Адапт. Попов: Took 488 iterations and 0.32 seconds to converge.
# 		Кеш. адапт. Попов: Took 488 iterations and 0.14 seconds to converge.
#
# 	Try #5:
# 		Адапт. Корпелевич: Took 279 iterations and 0.15 seconds to converge.
# 		Кеш. адапт. Корпелевич: Took 279 iterations and 0.10 seconds to converge.
# 		Адапт. Tseng: Took 656 iterations and 0.33 seconds to converge.
# 		Кеш. адапт. Tseng: Took 656 iterations and 0.17 seconds to converge.
# 		Адапт. Попов: Took 392 iterations and 0.46 seconds to converge.
# 		Кеш. адапт. Попов: Took 392 iterations and 0.29 seconds to converge.
#
#
# Розмір задачі = 500:
# 	Try #1:
# 		Адапт. Корпелевич: Took 421 iterations and 0.86 seconds to converge.
# 		Кеш. адапт. Корпелевич: Took 421 iterations and 0.63 seconds to converge.
# 		Адапт. Tseng: Took 800 iterations and 1.14 seconds to converge.
# 		Кеш. адапт. Tseng: Took 800 iterations and 0.34 seconds to converge.
# 		Адапт. Попов: Took 564 iterations and 0.47 seconds to converge.
# 		Кеш. адапт. Попов: Took 564 iterations and 0.46 seconds to converge.
#
# 	Try #2:
# 		Адапт. Корпелевич: Took 411 iterations and 0.78 seconds to converge.
# 		Кеш. адапт. Корпелевич: Took 411 iterations and 0.61 seconds to converge.
# 		Адапт. Tseng: Took 944 iterations and 1.40 seconds to converge.
# 		Кеш. адапт. Tseng: Took 944 iterations and 0.55 seconds to converge.
# 		Адапт. Попов: Took 548 iterations and 0.47 seconds to converge.
# 		Кеш. адапт. Попов: Took 548 iterations and 0.36 seconds to converge.
#
# 	Try #3:
# 		Адапт. Корпелевич: Took 469 iterations and 0.87 seconds to converge.
# 		Кеш. адапт. Корпелевич: Took 469 iterations and 0.70 seconds to converge.
# 		Адапт. Tseng: Took 977 iterations and 1.68 seconds to converge.
# 		Кеш. адапт. Tseng: Took 977 iterations and 0.89 seconds to converge.
# 		Адапт. Попов: Took 635 iterations and 0.79 seconds to converge.
# 		Кеш. адапт. Попов: Took 635 iterations and 0.41 seconds to converge.
#
# 	Try #4:
# 		Адапт. Корпелевич: Took 371 iterations and 0.38 seconds to converge.
# 		Кеш. адапт. Корпелевич: Took 371 iterations and 0.57 seconds to converge.
# 		Адапт. Tseng: Took 827 iterations and 1.23 seconds to converge.
# 		Кеш. адапт. Tseng: Took 827 iterations and 0.76 seconds to converge.
# 		Адапт. Попов: Took 502 iterations and 0.88 seconds to converge.
# 		Кеш. адапт. Попов: Took 502 iterations and 0.32 seconds to converge.
#
# 	Try #5:
# 		Адапт. Корпелевич: Took 379 iterations and 0.33 seconds to converge.
# 		Кеш. адапт. Корпелевич: Took 379 iterations and 0.23 seconds to converge.
# 		Адапт. Tseng: Took 813 iterations and 1.10 seconds to converge.
# 		Кеш. адапт. Tseng: Took 813 iterations and 0.74 seconds to converge.
# 		Адапт. Попов: Took 507 iterations and 0.97 seconds to converge.
# 		Кеш. адапт. Попов: Took 507 iterations and 0.65 seconds to converge.
#
#
# Розмір задачі = 1000:
# 	Try #1:
# 		Адапт. Корпелевич: Took 476 iterations and 2.00 seconds to converge.
# 		Кеш. адапт. Корпелевич: Took 476 iterations and 0.94 seconds to converge.
# 		Адапт. Tseng: Took 1048 iterations and 3.60 seconds to converge.
# 		Кеш. адапт. Tseng: Took 1048 iterations and 1.66 seconds to converge.
# 		Адапт. Попов: Took 612 iterations and 2.30 seconds to converge.
# 		Кеш. адапт. Попов: Took 612 iterations and 0.89 seconds to converge.
#
# 	Try #2:
# 		Адапт. Корпелевич: Took 454 iterations and 1.93 seconds to converge.
# 		Кеш. адапт. Корпелевич: Took 454 iterations and 1.27 seconds to converge.
# 		Адапт. Tseng: Took 1008 iterations and 3.54 seconds to converge.
# 		Кеш. адапт. Tseng: Took 1008 iterations and 1.52 seconds to converge.
# 		Адапт. Попов: Took 599 iterations and 2.53 seconds to converge.
# 		Кеш. адапт. Попов: Took 599 iterations and 1.12 seconds to converge.
#
# 	Try #3:
# 		Адапт. Корпелевич: Took 398 iterations and 1.77 seconds to converge.
# 		Кеш. адапт. Корпелевич: Took 398 iterations and 1.05 seconds to converge.
# 		Адапт. Tseng: Took 918 iterations and 3.14 seconds to converge.
# 		Кеш. адапт. Tseng: Took 918 iterations and 1.41 seconds to converge.
# 		Адапт. Попов: Took 542 iterations and 1.98 seconds to converge.
# 		Кеш. адапт. Попов: Took 542 iterations and 0.89 seconds to converge.
#
# 	Try #4:
# 		Адапт. Корпелевич: Took 406 iterations and 2.03 seconds to converge.
# 		Кеш. адапт. Корпелевич: Took 406 iterations and 1.40 seconds to converge.
# 		Адапт. Tseng: Took 915 iterations and 3.54 seconds to converge.
# 		Кеш. адапт. Tseng: Took 915 iterations and 1.81 seconds to converge.
# 		Адапт. Попов: Took 567 iterations and 2.52 seconds to converge.
# 		Кеш. адапт. Попов: Took 567 iterations and 0.85 seconds to converge.
#
# 	Try #5:
# 		Адапт. Корпелевич: Took 523 iterations and 2.02 seconds to converge.
# 		Кеш. адапт. Корпелевич: Took 523 iterations and 1.01 seconds to converge.
# 		Адапт. Tseng: Took 1084 iterations and 5.79 seconds to converge.
# 		Кеш. адапт. Tseng: Took 1084 iterations and 2.38 seconds to converge.
# 		Адапт. Попов: Took 710 iterations and 2.99 seconds to converge.
# 		Кеш. адапт. Попов: Took 710 iterations and 1.14 seconds to converge.

# %%
for algo in algos:
    for size in sizes:
        iters[algo][size] = (int(np.mean(iters[algo][size])), int(np.std(iters[algo][size])))
        times[algo][size] = (np.mean(times[algo][size]), np.std(times[algo][size]))

# %%
save_results_to_tbl_pm(times, sizes,
    fn='problem-2-adapt-time',
    caption='Час виконання, секунд')
save_results_to_tbl_pm(iters, sizes,
    fn='problem-2-adapt-iter',
    caption='Число ітерацій')

# %%
save_results_to_img_pm(times, sizes,
    fn='problem-2-adapt-time',
    styles=('r-', 'r--', 'g-', 'g--', 'b-', 'b--'),
    title='Час виконання, секунд')

# %% [markdown]
# # Задача 4

# %%
def generate_tridiagonal_matrix(size: int) -> np.matrix:
    d = np.zeros((size, size))
    for row in range(size):
        d[row, row] = 4
        if row != 0:
            d[row, row - 1] = 1
        if row + 1 != size:
            d[row, row + 1] = -2
    c = -np.ones(size)
    return d, c

# %%
sizes = (500, 1_000, 2_000, 5_000)
algos = ('Адапт. Корпелевич', 'Кеш. адапт. Корпелевич',
         'Адапт. Tseng', 'Кеш. адапт. Tseng',
         'Адапт. Попов', 'Кеш. адапт. Попов')
iters, times = {algo: {} for algo in algos}, {algo: {} for algo in algos}

# %%
for size in sizes:
    print(f'Розмір задачі = {size}:')
    d, c = generate_tridiagonal_matrix(size)

    def f(x: np.array) -> np.array:
        y = np.hstack([[0], x, [0]])
        f1 = y[1:-1] ** 2 + y[:-2] ** 2 + y[1:-1] * y[:-2] + y[1:-1] * y[2:]
        return f1 + d.dot(x) + c

    print('\tАдапт. Корпелевич:', end=' ')
    _, iters['Адапт. Корпелевич'][size], times['Адапт. Корпелевич'][size] = \
          adaptive_korpelevich(x_initial=np.ones(size), tau=.4, lambda_initial=1,
                               A=f, ProjectionOntoC=lambda x: np.maximum(x, np.zeros(x.shape[0])),
                               tolerance=1e-6, max_iterations=1e4, debug=True)

    print('\tКеш. адапт. Корпелевич:', end=' ')
    _, iters['Кеш. адапт. Корпелевич'][size], times['Кеш. адапт. Корпелевич'][size] = \
          cached_adaptive_korpelevich(x_initial=np.ones(size), tau=.4, lambda_initial=1,
                                      A=f, ProjectionOntoC=lambda x: np.maximum(x, np.zeros(x.shape[0])),
                                      tolerance=1e-6, max_iterations=1e4, debug=True)

    print('\tАдапт. Tseng:', end=' ')
    _, iters['Адапт. Tseng'][size], times['Адапт. Tseng'][size] = \
          adaptive_tseng(x_initial=np.ones(size), tau=.4, lambda_initial=1,
                         A=f, ProjectionOntoC=lambda x: np.maximum(x, np.zeros(x.shape[0])),
                         tolerance=1e-6, max_iterations=1e4, debug=True)

    print('\tКеш. адапт. Tseng:', end=' ')
    _, iters['Кеш. адапт. Tseng'][size], times['Кеш. адапт. Tseng'][size] = \
          cached_adaptive_tseng(x_initial=np.ones(size), tau=.4, lambda_initial=1,
                                A=f, ProjectionOntoC=lambda x: np.maximum(x, np.zeros(x.shape[0])),
                                tolerance=1e-6, max_iterations=1e4, debug=True)

    print('\tАдапт. Попов:', end=' ')
    _, iters['Адапт. Попов'][size], times['Адапт. Попов'][size] = \
          adaptive_popov(x_initial=np.ones(size), y_initial=np.ones(size),
                         tau=.4, lambda_initial=1,
                         A=f, ProjectionOntoC=lambda x: np.maximum(x, np.zeros(x.shape[0])),
                         tolerance=1e-6, max_iterations=1e4, debug=True)

    print("\tКеш. адапт. Попов: ", end="")
    _, iters['Кеш. адапт. Попов'][size], times['Кеш. адапт. Попов'][size] = \
          cached_adaptive_popov(x_initial=np.ones(size), y_initial=np.ones(size),
                                tau=.4, lambda_initial=1,
                                A=f, ProjectionOntoC=lambda x: np.maximum(x, np.zeros(x.shape[0])),
                                tolerance=1e-6, max_iterations=1e4, debug=True)
    
    print()
# Out:
# Розмір задачі = 500:
# 	Адапт. Корпелевич: Took 111 iterations and 0.19 seconds to converge.
# 	Кеш. адапт. Корпелевич: Took 111 iterations and 0.10 seconds to converge.
# 	Адапт. Tseng: Took 558 iterations and 1.03 seconds to converge.
# 	Кеш. адапт. Tseng: Took 558 iterations and 0.30 seconds to converge.
# 	Адапт. Попов: Took 87 iterations and 0.11 seconds to converge.
# 	Кеш. адапт. Попов: Took 87 iterations and 0.03 seconds to converge.
#
# Розмір задачі = 1000:
# 	Адапт. Корпелевич: Took 113 iterations and 0.36 seconds to converge.
# 	Кеш. адапт. Корпелевич: Took 113 iterations and 0.14 seconds to converge.
# 	Адапт. Tseng: Took 572 iterations and 2.26 seconds to converge.
# 	Кеш. адапт. Tseng: Took 572 iterations and 0.51 seconds to converge.
# 	Адапт. Попов: Took 89 iterations and 0.22 seconds to converge.
# 	Кеш. адапт. Попов: Took 89 iterations and 0.06 seconds to converge.
#
# Розмір задачі = 2000:
# 	Адапт. Корпелевич: Took 116 iterations and 1.89 seconds to converge.
# 	Кеш. адапт. Корпелевич: Took 116 iterations and 0.64 seconds to converge.
# 	Адапт. Tseng: Took 587 iterations and 11.37 seconds to converge.
# 	Кеш. адапт. Tseng: Took 587 iterations and 3.05 seconds to converge.
# 	Адапт. Попов: Took 91 iterations and 1.64 seconds to converge.
# 	Кеш. адапт. Попов: Took 91 iterations and 0.25 seconds to converge.
#
# Розмір задачі = 5000:
# 	Адапт. Корпелевич: Took 119 iterations and 12.39 seconds to converge.
# 	Кеш. адапт. Корпелевич: Took 119 iterations and 4.11 seconds to converge.
# 	Адапт. Tseng: Took 605 iterations and 76.47 seconds to converge.
# 	Кеш. адапт. Tseng: Took 605 iterations and 21.68 seconds to converge.
# 	Адапт. Попов: Took 94 iterations and 9.99 seconds to converge.
# 	Кеш. адапт. Попов: Took 94 iterations and 1.71 seconds to converge.

# %%
save_results_to_tbl(times, sizes,
    fn='problem-4-adapt-time',
    caption='Час виконання, секунд')
save_results_to_tbl(iters, sizes,
    fn='problem-4-adapt-iter',
    caption='Число ітерацій')

# %%
save_results_to_img(times, sizes,
    fn='problem-4-adapt-time',
    styles=('r-', 'r--', 'g-', 'g--', 'b-', 'b--'),
    title='Час виконання, секунд')

# %%
def generate_sparse_tridiagonal_matrix(size: int) -> np.matrix:
    data, rows, cols = [], [], []
    for row in range(size):
        if row != 0:
            rows.append(row)
            cols.append(row - 1)
            data.append(1)
        rows.append(row)
        cols.append(row)
        data.append(4)
        if row + 1 != size:
            rows.append(row)
            cols.append(row + 1)
            data.append(-2)
    d = sparse.coo_matrix((data, (rows, cols)), shape=(size, size))
    c = -np.ones(size)
    return d, c

# %%
sizes = (20_000, 50_000, 100_000, 200_000)
algos = ('Адапт. Корпелевич', 'Кеш. адапт. Корпелевич',
         'Адапт. Tseng', 'Кеш. адапт. Tseng',
         'Адапт. Попов', 'Кеш. адапт. Попов')
iters, times = {algo: {} for algo in algos}, {algo: {} for algo in algos}

# %%
for size in sizes:
    print(f'Розмір задачі = {size}:')
    d, c = generate_sparse_tridiagonal_matrix(size)

    def f(x: np.array) -> np.array:
        y = np.hstack([[0], x, [0]])
        f1 = y[1:-1] ** 2 + y[:-2] ** 2 + y[1:-1] * y[:-2] + y[1:-1] * y[2:]
        return f1 + d.dot(x) + c

    print('\tАдапт. Корпелевич:', end=' ')
    _, iters['Адапт. Корпелевич'][size], times['Адапт. Корпелевич'][size] = \
          adaptive_korpelevich(x_initial=np.ones(size), tau=.4, lambda_initial=1,
                               A=f, ProjectionOntoC=lambda x: np.maximum(x, np.zeros(x.shape[0])),
                               tolerance=1e-6, max_iterations=1e4, debug=True)

    print('\tКеш. адапт. Корпелевич:', end=' ')
    _, iters['Кеш. адапт. Корпелевич'][size], times['Кеш. адапт. Корпелевич'][size] = \
          cached_adaptive_korpelevich(x_initial=np.ones(size), tau=.4, lambda_initial=1,
                                      A=f, ProjectionOntoC=lambda x: np.maximum(x, np.zeros(x.shape[0])),
                                      tolerance=1e-6, max_iterations=1e4, debug=True)

    print('\tАдапт. Tseng:', end=' ')
    _, iters['Адапт. Tseng'][size], times['Адапт. Tseng'][size] = \
          adaptive_tseng(x_initial=np.ones(size), tau=.4, lambda_initial=1,
                         A=f, ProjectionOntoC=lambda x: np.maximum(x, np.zeros(x.shape[0])),
                         tolerance=1e-6, max_iterations=1e4, debug=True)

    print('\tКеш. адапт. Tseng:', end=' ')
    _, iters['Кеш. адапт. Tseng'][size], times['Кеш. адапт. Tseng'][size] = \
          cached_adaptive_tseng(x_initial=np.ones(size), tau=.4, lambda_initial=1,
                                A=f, ProjectionOntoC=lambda x: np.maximum(x, np.zeros(x.shape[0])),
                                tolerance=1e-6, max_iterations=1e4, debug=True)

    print('\tАдапт. Попов:', end=' ')
    _, iters['Адапт. Попов'][size], times['Адапт. Попов'][size] = \
          adaptive_popov(x_initial=np.ones(size), y_initial=np.ones(size),
                         tau=.4, lambda_initial=1,
                         A=f, ProjectionOntoC=lambda x: np.maximum(x, np.zeros(x.shape[0])),
                         tolerance=1e-6, max_iterations=1e4, debug=True)

    print("\tКеш. адапт. Попов: ", end="")
    _, iters['Кеш. адапт. Попов'][size], times['Кеш. адапт. Попов'][size] = \
          cached_adaptive_popov(x_initial=np.ones(size), y_initial=np.ones(size),
                                tau=.4, lambda_initial=1,
                                A=f, ProjectionOntoC=lambda x: np.maximum(x, np.zeros(x.shape[0])),
                                tolerance=1e-6, max_iterations=1e4, debug=True)
    
    print()
# Out:
# Розмір задачі = 20000:
# 	Адапт. Корпелевич: Took 124 iterations and 0.26 seconds to converge.
# 	Кеш. адапт. Корпелевич: Took 124 iterations and 0.11 seconds to converge.
# 	Адапт. Tseng: Took 634 iterations and 2.31 seconds to converge.
# 	Кеш. адапт. Tseng: Took 634 iterations and 1.34 seconds to converge.
# 	Адапт. Попов: Took 98 iterations and 0.48 seconds to converge.
# 	Кеш. адапт. Попов: Took 98 iterations and 0.09 seconds to converge.
#
# Розмір задачі = 50000:
# 	Адапт. Корпелевич: Took 127 iterations and 1.06 seconds to converge.
# 	Кеш. адапт. Корпелевич: Took 127 iterations and 0.51 seconds to converge.
# 	Адапт. Tseng: Took 653 iterations and 8.71 seconds to converge.
# 	Кеш. адапт. Tseng: Took 653 iterations and 3.12 seconds to converge.
# 	Адапт. Попов: Took 101 iterations and 0.88 seconds to converge.
# 	Кеш. адапт. Попов: Took 101 iterations and 0.32 seconds to converge.
#
# Розмір задачі = 100000:
# 	Адапт. Корпелевич: Took 130 iterations and 4.53 seconds to converge.
# 	Кеш. адапт. Корпелевич: Took 130 iterations and 1.13 seconds to converge.
# 	Адапт. Tseng: Took 667 iterations and 18.13 seconds to converge.
# 	Кеш. адапт. Tseng: Took 667 iterations and 7.51 seconds to converge.
# 	Адапт. Попов: Took 103 iterations and 2.82 seconds to converge.
# 	Кеш. адапт. Попов: Took 103 iterations and 0.66 seconds to converge.
#
# Розмір задачі = 200000:
# 	Адапт. Корпелевич: Took 132 iterations and 16.67 seconds to converge.
# 	Кеш. адапт. Корпелевич: Took 132 iterations and 6.39 seconds to converge.
# 	Адапт. Tseng: Took 682 iterations and 95.99 seconds to converge.
# 	Кеш. адапт. Tseng: Took 682 iterations and 37.94 seconds to converge.
# 	Адапт. Попов: Took 105 iterations and 12.93 seconds to converge.
# 	Кеш. адапт. Попов: Took 105 iterations and 2.79 seconds to converge.

# %%
save_results_to_tbl(times, sizes,
    fn='problem-4-sparse-adapt-time',
    caption='Час виконання, секунд')
save_results_to_tbl(iters, sizes,
    fn='problem-4-sparse-adapt-iter',
    caption='Число ітерацій')

# %%
save_results_to_img(times, sizes,
    fn='problem-4-sparse-adapt-time',
    styles=('r-', 'r--', 'g-', 'g--', 'b-', 'b--'),
    title='Час виконання, секунд')
